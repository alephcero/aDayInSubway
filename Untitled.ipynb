# %%
import pandas as pd

# %%
data = pd.read_csv('carto2.csv',
                  #parse_dates = [2]
                  )
data.head()
# Out:
#      LINEA ESTACION                DESDE      TOTAL          X         Y
# 0  LINEA_A   ACOYTE  2017-05-23 05:00:00   9.394309 -58.436429 -34.61828
# 1  LINEA_A   ACOYTE  2017-05-23 05:15:00  14.713115 -58.436429 -34.61828
# 2  LINEA_A   ACOYTE  2017-05-23 05:30:00  17.819672 -58.436429 -34.61828
# 3  LINEA_A   ACOYTE  2017-05-23 05:45:00  20.183673 -58.436429 -34.61828
# 4  LINEA_A   ACOYTE  2017-05-23 06:00:00  37.963115 -58.436429 -34.61828

# %%
len(data.DESDE.unique())
# Out:
# 74

# %%
data.to_csv('carto2.csv',index=False,encoding='utf-8')

# %%
data.sort_values(by=['TOTAL'],ascending=False)
# Out:
#         LINEA              ESTACION               DESDE       TOTAL  \
# 1950  LINEA_B       LEANDRO N. ALEM 2017-05-23 18:00:00  187.939766
# 1951  LINEA_B       LEANDRO N. ALEM 2017-05-23 18:15:00  187.496487
# 1877  LINEA_B               FLORIDA 2017-05-23 18:00:00  157.214174
# 1947  LINEA_B       LEANDRO N. ALEM 2017-05-23 17:15:00  154.290772
# 857   LINEA_A         PLAZA DE MAYO 2017-05-23 18:15:00  149.376464
# 3558  LINEA_D              CATEDRAL 2017-05-23 18:00:00  148.803453
# 3559  LINEA_D              CATEDRAL 2017-05-23 18:15:00  147.563364
# 856   LINEA_A         PLAZA DE MAYO 2017-05-23 18:00:00  146.282667
# 2348  LINEA_B                 ROSAS 2017-05-23 08:15:00  146.053933
# 1948  LINEA_B       LEANDRO N. ALEM 2017-05-23 17:30:00  145.197093
# 2640  LINEA_C          CONSTITUCION 2017-05-23 08:15:00  144.526724
# 1952  LINEA_B       LEANDRO N. ALEM 2017-05-23 18:30:00  143.477166
# 1949  LINEA_B       LEANDRO N. ALEM 2017-05-23 17:45:00  138.551925
# ...
